# %%
import networkx as nx
import matplotlib.pyplot as plt
import queue

# %%
# load the data of a graph
G2=nx.read_edgelist('test2.edgelist', nodetype=int)
nx.draw_networkx(G2)
plt.show()

# %%
def euler(g):
    for i in G2.degree:
        if i[1] % 2 == 1:
            return False
    return True
euler(G2)
# Out:
# True

# %%
def deg(g):
    for i in G2.degree:
        print(i[1])
deg(G2)
# Out:
# 2
# 4
# 4
# 4
# 4
# 2

# %%
print(G2.degree)
# Out:
# [(1, 2), (2, 4), (4, 4), (3, 4), (5, 4), (6, 2)]
